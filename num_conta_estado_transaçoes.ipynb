# %%
import pandas as pd

# %%
clientes = pd.read_csv("clientes.csv")
contas = pd.read_csv("contas1.0.csv")
transacoes = pd.read_csv("transcoes1.0.csv")

# %%
contas
# Out:
#      Unnamed: 0  num_conta  cod_cliente  cod_agencia  cod_colaborador  \
# 0             0         53           53            1                7
# 1             1        190          190            1                7
# 2             2        191          191            1                7
# 3             3        203          203            1                7
# 4             4        254          254            1                7
# ..          ...        ...          ...          ...              ...
# 994         994        466          466           10                8
# 995         995        764          764           10                8
# 996         996        488          488           10               18
# 997         997        395          395           10               95
# 998         998        355          355           10              100
#
#     tipo_conta            data_abertura  saldo_total  saldo_disponivel  \
# ...

# %%
transacoes
# Out:
#        Unnamed: 0  cod_transacao  num_conta           data_transacao  \
# 0               0           3100        256  2020-05-22 03:15:21 UTC
# 1               1          28405        256  2021-06-29 11:52:38 UTC
# 2               2           3190        256  2020-06-06 02:06:41 UTC
# 3               3           4466        256  2020-06-06 04:16:53 UTC
# 4               4           8455        256  2020-06-06 11:27:06 UTC
# ...           ...            ...        ...                      ...
# 71994       71994          13438        252  2019-10-11 03:44:23 UTC
# 71995       71995          21265        252  2020-05-04 18:36:40 UTC
# 71996       71996          24126        252  2020-05-16 16:01:42 UTC
# 71997       71997          31758        252  2020-09-03 12:43:10 UTC
# 71998       71998          36759        252  2021-01-05 06:36:01 UTC
#
#             nome_transacao  valor_transacao     tipo_agencia
# 0                    Saque          -130.00  Agencia Digital
# ...

# %%
clientes
# Out:
#      cod_cliente primeiro_nome   ultimo_nome                            email  \
# 0             28       Sabrina          Dias     moreiraemanuelly@example.org
# 1            674   Luiz Felipe          Dias        pedroferreira@example.org
# 2            693         Renan          Dias               ogomes@example.net
# 3            743         Clara          Dias        rafaelcorreia@example.org
# 4            769         André          Dias             danilo33@example.org
# ..           ...           ...           ...                              ...
# 993          730       Bárbara  da Conceição  enzo-gabrielcardoso@example.com
# 994          772        Daniel  da Conceição             raquel97@example.com
# 995          837          Theo  da Conceição           ninacastro@example.org
# 996          845   Pedro Lucas  da Conceição        silveirabruno@example.com
# 997          853        Milena  da Conceição        ribeirodanilo@example.net
#
# ...

# %%
clientes["estado"] = clientes["endereco"].str.slice(start=-2)
clientes
# Out:
#      cod_cliente primeiro_nome   ultimo_nome                            email  \
# 0             28       Sabrina          Dias     moreiraemanuelly@example.org
# 1            674   Luiz Felipe          Dias        pedroferreira@example.org
# 2            693         Renan          Dias               ogomes@example.net
# 3            743         Clara          Dias        rafaelcorreia@example.org
# 4            769         André          Dias             danilo33@example.org
# ..           ...           ...           ...                              ...
# 993          730       Bárbara  da Conceição  enzo-gabrielcardoso@example.com
# 994          772        Daniel  da Conceição             raquel97@example.com
# 995          837          Theo  da Conceição           ninacastro@example.org
# 996          845   Pedro Lucas  da Conceição        silveirabruno@example.com
# 997          853        Milena  da Conceição        ribeirodanilo@example.net
#
# ...

# %%
contas = contas.merge(clientes[["cod_cliente", "estado"]])
contas
# Out:
#      Unnamed: 0  num_conta  cod_cliente  cod_agencia  cod_colaborador  \
# 0             0         53           53            1                7
# 1             1        190          190            1                7
# 2             2        191          191            1                7
# 3             3        203          203            1                7
# 4             4        254          254            1                7
# ..          ...        ...          ...          ...              ...
# 993         994        466          466           10                8
# 994         995        764          764           10                8
# 995         996        488          488           10               18
# 996         997        395          395           10               95
# 997         998        355          355           10              100
#
#     tipo_conta            data_abertura  saldo_total  saldo_disponivel  \
# ...

# %%
transacoes = transacoes.merge(contas[["num_conta", "estado"]])
transacoes
# Out:
#        Unnamed: 0  cod_transacao  num_conta           data_transacao  \
# 0               0           3100        256  2020-05-22 03:15:21 UTC
# 1               1          28405        256  2021-06-29 11:52:38 UTC
# 2               2           3190        256  2020-06-06 02:06:41 UTC
# 3               3           4466        256  2020-06-06 04:16:53 UTC
# 4               4           8455        256  2020-06-06 11:27:06 UTC
# ...           ...            ...        ...                      ...
# 71916       71994          13438        252  2019-10-11 03:44:23 UTC
# 71917       71995          21265        252  2020-05-04 18:36:40 UTC
# 71918       71996          24126        252  2020-05-16 16:01:42 UTC
# 71919       71997          31758        252  2020-09-03 12:43:10 UTC
# 71920       71998          36759        252  2021-01-05 06:36:01 UTC
#
#             nome_transacao  valor_transacao     tipo_agencia estado
# 0                    Saque          -130.00  Agencia Digital     SP
# ...

# %%
transacoes.to_csv("transacoes2.0.csv")
clientes.to_csv("clientes1.0.csv")
contas.to_csv("contas2.0.csv")
