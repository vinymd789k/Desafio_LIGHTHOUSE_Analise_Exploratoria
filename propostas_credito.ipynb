# %%
import pandas as pd

# %%
credito = pd.read_csv("propostas_credito.csv")
contas1_0 = pd.read_csv("contas1.0.csv")

# %%
credito
# Out:
#       cod_proposta  cod_cliente  cod_colaborador    data_entrada_proposta  \
# 0              116          338                1  2014-05-30 18:43:12 UTC
# 1              715           45                1  2021-06-17 13:09:32 UTC
# 2              755          494                1  2021-08-10 04:24:02 UTC
# 3              953          381                1  2011-02-23 07:57:58 UTC
# 4             1046          176                1  2010-11-15 16:03:28 UTC
# ...            ...          ...              ...                      ...
# 1995          1758          176               99  2010-01-10 08:12:47 UTC
# 1996           582          241              100  2019-02-25 05:03:22 UTC
# 1997           970          106              100  2011-06-05 04:13:16 UTC
# 1998          1361          814              100  2020-07-25 20:50:30 UTC
# 1999          1562          998              100  2017-03-22 12:25:42 UTC
#
#       taxa_juros_mensal  valor_proposta  valor_financiamento  valor_entrada  \
# ...

# %%
contas1_0
# Out:
#      Unnamed: 0  num_conta  cod_cliente  cod_agencia  cod_colaborador  \
# 0             0         53           53            1                7
# 1             1        190          190            1                7
# 2             2        191          191            1                7
# 3             3        203          203            1                7
# 4             4        254          254            1                7
# ..          ...        ...          ...          ...              ...
# 994         994        466          466           10                8
# 995         995        764          764           10                8
# 996         996        488          488           10               18
# 997         997        395          395           10               95
# 998         998        355          355           10              100
#
#     tipo_conta            data_abertura  saldo_total  saldo_disponivel  \
# ...

# %%
credito = credito.merge(contas1_0[["cod_cliente", "tipo_agencia"]])
credito
# Out:
#       cod_proposta  cod_cliente  cod_colaborador    data_entrada_proposta  \
# 0              116          338                1  2014-05-30 18:43:12 UTC
# 1              485          338               20  2021-03-30 08:59:12 UTC
# 2             1551          338               59  2019-06-04 03:50:19 UTC
# 3             1369          338               72  2013-08-30 11:18:10 UTC
# 4              715           45                1  2021-06-17 13:09:32 UTC
# ...            ...          ...              ...                      ...
# 1995           362          263               96  2012-05-17 00:41:02 UTC
# 1996           677          320               98  2014-06-30 08:48:48 UTC
# 1997           904          361               98  2017-01-30 06:53:04 UTC
# 1998          1398          468               98  2019-09-29 03:45:17 UTC
# 1999           582          241              100  2019-02-25 05:03:22 UTC
#
#       taxa_juros_mensal  valor_proposta  valor_financiamento  valor_entrada  \
# ...

# %%
credito.to_csv("propostas_credito1.0.csv")
