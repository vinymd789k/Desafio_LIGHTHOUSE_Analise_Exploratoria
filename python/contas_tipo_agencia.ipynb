# %%
import pandas as pd

# %%
contas = pd.read_csv("contas.csv")
print(contas)
# Out:
#      num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0           53           53            1                7         PF
# 1          190          190            1                7         PF
# 2          191          191            1                7         PF
# 3          203          203            1                7         PF
# 4          254          254            1                7         PF
# ..         ...          ...          ...              ...        ...
# 994        466          466           10                8         PF
# 995        764          764           10                8         PF
# 996        488          488           10               18         PF
# 997        395          395           10               95         PF
# 998        355          355           10              100         PF
#
#                data_abertura  saldo_total  saldo_disponivel  \
# 0    2011-05-24 15:30:00 UTC    2984.7615           2814.67
# ...

# %%
contas["tipo_agencia"] = contas["cod_agencia"]
contas
# Out:
#      num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0           53           53            1                7         PF
# 1          190          190            1                7         PF
# 2          191          191            1                7         PF
# 3          203          203            1                7         PF
# 4          254          254            1                7         PF
# ..         ...          ...          ...              ...        ...
# 994        466          466           10                8         PF
# 995        764          764           10                8         PF
# 996        488          488           10               18         PF
# 997        395          395           10               95         PF
# 998        355          355           10              100         PF
#
#                data_abertura  saldo_total  saldo_disponivel  \
# 0    2011-05-24 15:30:00 UTC    2984.7615           2814.67
# ...

# %%
i = 1

for i in contas["tipo_agencia"]:
    
    contas["tipo_agencia"] = contas["tipo_agencia"].replace(i, "Agencia Fisica")

contas["tipo_agencia"][6] = "Agencia Digital"

contas["tipo_agencia"]
# Out:
# C:\Users\vini7\AppData\Local\Temp\ipykernel_15432\3413683453.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contas["tipo_agencia"][6] = "Agencia Digital"
# 0      Agencia Fisica
# 1      Agencia Fisica
# 2      Agencia Fisica
# 3      Agencia Fisica
# 4      Agencia Fisica
#             ...
# 994    Agencia Fisica
# 995    Agencia Fisica
# 996    Agencia Fisica
# 997    Agencia Fisica
# 998    Agencia Fisica
# Name: tipo_agencia, Length: 999, dtype: object

# %%
contas.to_csv("contas1.0.csv")
