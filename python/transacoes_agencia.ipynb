# %%
import pandas as pd

# %%
contas1_0 = pd.read_csv("contas1.0.csv")
transacoes = pd.read_csv("transacoes.csv")

# %%
transacoes
# Out:
#        cod_transacao  num_conta                  data_transacao  \
# 0               3100        256         2020-05-22 03:15:21 UTC
# 1              28405        256         2021-06-29 11:52:38 UTC
# 2               1776        512         2020-05-17 13:04:50 UTC
# 3              14311        512         2020-09-06 02:55:34 UTC
# 4              25012        512         2020-10-16 09:26:52 UTC
# ...              ...        ...                             ...
# 71994          17007        764  2022-12-29 23:59:59.746608 UTC
# 71995          22320        764  2022-12-29 23:59:59.055028 UTC
# 71996           8697        509         2012-05-07 13:45:41 UTC
# 71997          11574        766         2015-09-19 05:13:07 UTC
# 71998          64396        766  2022-12-29 23:59:59.607373 UTC
#
#                          nome_transacao  valor_transacao
# 0                                 Saque           -130.0
# 1                                 Saque           -255.0
# ...

# %%
contas1_0
# Out:
#      Unnamed: 0  num_conta  cod_cliente  cod_agencia  cod_colaborador  \
# 0             0         53           53            1                7
# 1             1        190          190            1                7
# 2             2        191          191            1                7
# 3             3        203          203            1                7
# 4             4        254          254            1                7
# ..          ...        ...          ...          ...              ...
# 994         994        466          466           10                8
# 995         995        764          764           10                8
# 996         996        488          488           10               18
# 997         997        395          395           10               95
# 998         998        355          355           10              100
#
#     tipo_conta            data_abertura  saldo_total  saldo_disponivel  \
# ...

# %%
transacoes = transacoes.merge(contas1_0[["num_conta", "tipo_agencia"]])
transacoes
# Out:
#        cod_transacao  num_conta           data_transacao       nome_transacao  \
# 0               3100        256  2020-05-22 03:15:21 UTC                Saque
# 1              28405        256  2021-06-29 11:52:38 UTC                Saque
# 2               3190        256  2020-06-06 02:06:41 UTC        Compra Débito
# 3               4466        256  2020-06-06 04:16:53 UTC        Compra Débito
# 4               8455        256  2020-06-06 11:27:06 UTC        Compra Débito
# ...              ...        ...                      ...                  ...
# 71994          13438        252  2019-10-11 03:44:23 UTC  Depósito em espécie
# 71995          21265        252  2020-05-04 18:36:40 UTC  Depósito em espécie
# 71996          24126        252  2020-05-16 16:01:42 UTC  Depósito em espécie
# 71997          31758        252  2020-09-03 12:43:10 UTC  Depósito em espécie
# 71998          36759        252  2021-01-05 06:36:01 UTC  Depósito em espécie
#
# ...

# %%
transacoes.to_csv("transcoes1.0.csv")
